# %%
import os
import pandas as pd

from get_logger import logger
from preprocessor import Preprocessor

original_data_path = "../data/Software.json"
preprocessed_data_path = "../data/Software-Preprocessed-Visualization.json"

if os.path.isfile(preprocessed_data_path):
    logger.info(f"Reading data from {preprocessed_data_path}")
    reviews = pd.read_json(preprocessed_data_path, lines=True)
else:
    logger.info(f"Reading data from {original_data_path}")
    reviews = pd.read_json(original_data_path, lines=True)
    reviews = Preprocessor.clean_review_objects(reviews)
    reviews = Preprocessor.standardize_columns(reviews, ["vote", "reviewLength", "reviewAge"])
    reviews[["reviewText", "verified", "reviewLengthStd", "reviewAgeStd", "voteStd"]].to_json(
        preprocessed_data_path, lines=True, orient="records")
    
reviews.head()
# Out:
# [INFO] 2024-04-13 10:39:20 - 1372711453: Reading data from ../data/Software.json
#                    overall  verified           reviewTime      reviewerID  \
# asin
# 0073513458 447940        3         1  2014-01-23 00:00:00   AQ1AKPWOE6YKZ
# 0077410297 364892        4         1  2015-02-19 00:00:00  A2YY405YYFQ92I
#            364893        5         1  2014-09-15 00:00:00  A187HEUN892B56
#            364894        1         0  2014-08-26 00:00:00  A3ILZXWASQRBMY
#            364895        5         1  2014-01-08 00:00:00  A1B65SURHKN15T
#
#                          asin                                style  \
# asin
# 0073513458 447940  0073513458               {'Format:': ' CD-ROM'}
# 0077410297 364892  0077410297  {'Format:': ' Printed Access Code'}
#            364893  0077410297  {'Format:': ' Printed Access Code'}
#            364894  0077410297  {'Format:': ' Printed Access Code'}
#            364895  0077410297  {'Format:': ' Printed Access Code'}
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your dataframe is named df and "voteStd" is the column name
sns.histplot(reviews['voteStd'], kde=True, bins=50, color='skyblue', linewidth=0)
plt.title('Distribution of voteStd')
plt.xlabel('voteStd')
plt.ylabel('Frequency')
plt.show()

# %%
plt.boxplot(reviews['voteStd'])
plt.title('Boxplot of voteStd')
plt.ylabel('voteStd')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your dataframe is named df and "voteStd" is the column name
plt.figure(figsize=(10, 6))
sns.swarmplot(y=reviews['voteStd'], color="royalblue")
plt.title('Beeswarm plot of voteStd')
plt.ylabel('voteStd')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 6
#       4 # Assuming your dataframe is named df and "voteStd" is the column name
#       5 plt.figure(figsize=(10, 6))
# ----> 6 sns.swarmplot(y=reviews['voteStd'], color="royalblue")
#       7 plt.title('Beeswarm plot of voteStd')
#       8 plt.ylabel('voteStd')
#
# File ~\Documents\Repos\ms-aai-501-final-project\venv\Lib\site-packages\seaborn\categorical.py:2250, in swarmplot(data, x, y, hue, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, log_scale, native_scale, formatter, legend, warn_thresh, ax, **kwargs)
#    2242     linewidth = size / 10
#    2244 kwargs.update(dict(
#    2245     s=size ** 2,
#    2246     edgecolor=edgecolor,
#    2247     linewidth=linewidth,
#    2248 ))
# -> 2250 p.plot_swarms(
#    2251     dodge=dodge,
#    2252     color=color,
# ...
